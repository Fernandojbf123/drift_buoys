# %% [markdown]
# <b>Código principal para graficar los datos.</b>
# <p> Configurar fechas de carga, seriales de boyas y rutas para archivos en \Configs\configuracion_general.py </p>

# %%
####################### N O  T O C A R ############################################
# %load_ext autoreload
# %autoreload 2

import os
import sys

# Agrega la ruta raíz del proyecto si no está
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from Funciones.Graficado.graficar_series_y_guardar import *
from Funciones.Graficado.graficar_mapa_de_posiciones import *
##################################################################################

# %%
graficar_series_y_guardar()
# Out:
# Figura guardada correctamente en C:/Users/Atmosfera/Desktop/datos_procesados/doris/202512\SONDA_OCEANOGRAFICA_NS_4876187_REALT_20251201_20251231.png
# Figura guardada correctamente en C:/Users/Atmosfera/Desktop/datos_procesados/doris/202512\SONDA_OCEANOGRAFICA_NS_4878196_REALT_20251201_20251231.png
# Figura guardada correctamente en C:/Users/Atmosfera/Desktop/datos_procesados/doris/202512\SONDA_OCEANOGRAFICA_NS_4878205_REALT_20251201_20251217.png
# Figura guardada correctamente en C:/Users/Atmosfera/Desktop/datos_procesados/doris/202512\SONDA_OCEANOGRAFICA_NS_4878218_REALT_20251201_20251231.png

# %%
graficar_mapa_con_posiciones()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 graficar_mapa_con_posiciones()
#
# File c:\programacion\codigos_python\drift_buoys\Funciones\Graficado\graficar_mapa_de_posiciones.py:17, in graficar_mapa_con_posiciones()
#      12 """
#      13 Grafica un mapa de posiciones geográficas dentro de los límites dados.
#      14 Utiliza la función graficar_mapa_cartopy para crear el mapa base.
#      15 """
#      16 # Esto se carga desde el archivo de configuración
# ---> 17 coords_mapa = get_coordenadas_del_mapa()
#      18 lon_min = coords_mapa["lon_min"]
#      19 lon_max = coords_mapa["lon_max"]
#
# File c:\programacion\codigos_python\drift_buoys\Funciones\Utils\utils_get_config_vars.py:76, in get_coordenadas_del_mapa()
#      75 def get_coordenadas_del_mapa():
# ---> 76     return _get_config_value("coordenadas_del_mapa")
#
# File c:\programacion\codigos_python\drift_buoys\Funciones\Utils\utils_get_config_vars.py:9, in _get_config_value(key)
#       7 import importlib
#       8 importlib.reload(Configs.configuracion_general)
# ----> 9 return Configs.configuracion_general.general_config[key]
#
# KeyError: 'coordenadas_del_mapa'
