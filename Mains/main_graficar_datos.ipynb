# %% [markdown]
# <b>Código principal para graficar los datos.</b>
# <p> Configurar fechas de carga, seriales de boyas y rutas para archivos en \Configs\configuracion_general.py </p>

# %%
####################### N O  T O C A R ############################################
# %load_ext autoreload
# %autoreload 2

import os
import sys

# Agrega la ruta raíz del proyecto si no está
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from Funciones.Graficado.graficar_series_y_guardar import *
from Funciones.Graficado.graficar_mapa_de_posiciones import *
##################################################################################

# %%
graficar_series_y_guardar(mostrar_figura=False)

# %%
graficar_mapa_con_posiciones(mostrar_figura=False)
# Out:
# sonda 4876190 lat ini= 18.553612, lon ini= -93.304782
# Figura guardada correctamente en C:/Users/Atmosfera/Desktop/datos_procesados/doris/202601\MAPA_DE_TRAYECTORIAS_SONDA_OCEANOGRAFICANS_4876190_REALT_20260102_20260103.png
# sonda 4878196 lat ini= 20.108714, lon ini= -91.879756
# Figura guardada correctamente en C:/Users/Atmosfera/Desktop/datos_procesados/doris/202601\MAPA_DE_TRAYECTORIAS_SONDA_OCEANOGRAFICANS_4878196_REALT_20260101_20260105.png
# sonda 4876187 lat ini= 19.410943, lon ini= -91.826327
# Figura guardada correctamente en C:/Users/Atmosfera/Desktop/datos_procesados/doris/202601\MAPA_DE_TRAYECTORIAS_SONDA_OCEANOGRAFICANS_4876187_REALT_20260101_20260128.png
