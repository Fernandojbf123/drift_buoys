# %%
####################### N O  T O C A R ############################################
# %load_ext autoreload
# %autoreload 2

import os
import sys

# Agrega la ruta raíz del proyecto si no está
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from Funciones.Pruebas_lab.pruebas_lab_utils import *
##################################################################################

# %%
fecha_ini = pd.to_datetime("2025-12-30T8:50:00")
fecha_fin = pd.to_datetime("2025-12-31T14:39:00")   
seriales = ["4866704","4878221","4878503","4876191","4876190"]
ruta_a_carpeta = "C:/Users/Atmosfera/Desktop/datos_procesados/doris/202601/pruebas_lab"

# %%
diccionarios = {}
for serial in seriales:
    dic = generar_datos(fecha_inicio=fecha_ini, fecha_fin=fecha_fin, periodo=45, variacion=5)
    df = pd.DataFrame(dic)
    diccionarios[serial] = df
    file_path = os.path.join(ruta_a_carpeta, f"prueba_en_tierra_{serial}_TOTAL.csv")
    df.to_csv(file_path, index=False)

# %%
# diccionarios["4878221"].head()
