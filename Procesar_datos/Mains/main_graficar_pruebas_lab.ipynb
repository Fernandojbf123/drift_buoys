# %% [markdown]
# <b>Código principal para graficar los datos.</b>
# <p> Configurar fechas de carga, seriales de boyas y rutas para archivos en \Configs\configuracion_general.py </p>

# %%
####################### N O  T O C A R ############################################
# %load_ext autoreload
# %autoreload 2

import os
import sys

# Agrega la ruta raíz del proyecto si no está
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from services.Graficado.graficar_series_laboratorio_y_guardar import *
from services.Graficado.graficar_mapa_prueba_lab import *
from services.Graficado.graficar_mapa_de_despliegue import *
##################################################################################
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Esta figura se hace usando los datos de lab y los datos de la página web.
graficar_series_laboratorio_y_guardar(mostrar_figura=False) # Revisar los n_ticks en calcular_xticks ; esto sigue mal
# Out:
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.1\202606\pruebas_lab\pruebas_de_voltaje_laboratorio.png

# %%
# Este mapa se hace usando los datos de lab y los datos de la página web.
graficar_mapa_prueba_lab(mostrar_figura=False)
# Out:
# c:\Users\Atmosfera\Documents\drift_buoys\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.1\202606\pruebas_lab\mapa_de_prueba_lab.png

# %%
# Este mapa se hace usando los datos descargados de la página web
graficar_mapa_de_despliegue(mostrar_figura=False)
# Out:
# c:\Users\Atmosfera\Documents\drift_buoys\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.1\202606\pruebas_lab\mapa_de_despliegue.png
