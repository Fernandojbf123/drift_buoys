# %% [markdown]
# <b>Código principal para graficar los datos.</b>
# <p> Configurar fechas de carga, seriales de boyas y rutas para archivos en \Configs\configuracion_general.py </p>

# %%
####################### N O  T O C A R ############################################
# %load_ext autoreload
# %autoreload 2

import os
import sys

# Agrega la ruta raíz del proyecto si no está
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from services.Graficado.graficar_series_y_guardar import *
from services.Graficado.graficar_mapa_de_posiciones import *
from services.Graficado.graficar_mapa_de_despliegue import *
##################################################################################
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Esta figura se hace usando los datos de lab y los datos de la página web.
graficar_series_y_guardar(mostrar_figura=False) # Revisar los n_ticks en calcular_xticks ; esto sigue mal
# Out:
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\SONDA_OCEANOGRAFICA_NS_4910070_REALT_20260526_20260531.png
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\SONDA_OCEANOGRAFICA_NS_4912213_REALT_20260526_20260531.png
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\SONDA_OCEANOGRAFICA_NS_4904116_REALT_20260526_20260531.png
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\SONDA_OCEANOGRAFICA_NS_4901427_REALT_20260526_20260531.png
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\SONDA_OCEANOGRAFICA_NS_4912212_REALT_20260526_20260531.png

# %%
# Este mapa se hace usando los datos de lab y los datos de la página web.
graficar_mapa_con_posiciones(mostrar_figura=False)
# Out:
# c:\Users\Atmosfera\Documents\drift_buoys\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# sonda 4910070 lat ini= 19.393562, lon ini= -92.04247
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\MAPA_DE_TRAYECTORIAS_SONDA_OCEANOGRAFICANS_4910070_REALT_20260526_20260531.png
# sonda 4912213 lat ini= 19.398594, lon ini= -92.024209
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\MAPA_DE_TRAYECTORIAS_SONDA_OCEANOGRAFICANS_4912213_REALT_20260526_20260531.png
# sonda 4904116 lat ini= 19.362491, lon ini= -92.052748
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\MAPA_DE_TRAYECTORIAS_SONDA_OCEANOGRAFICANS_4904116_REALT_20260526_20260531.png
# sonda 4901427 lat ini= 19.365045, lon ini= -92.035711
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\MAPA_DE_TRAYECTORIAS_SONDA_OCEANOGRAFICANS_4901427_REALT_20260526_20260531.png
# sonda 4912212 lat ini= 19.366354, lon ini= -92.017772
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\MAPA_DE_TRAYECTORIAS_SONDA_OCEANOGRAFICANS_4912212_REALT_20260526_20260531.png
