# %% [markdown]
# <b>Código principal para graficar los datos.</b>
# <p> Configurar fechas de carga, seriales de boyas y rutas para archivos en \Configs\configuracion_general.py </p>

# %%
####################### N O  T O C A R ############################################
# %load_ext autoreload
# %autoreload 2

import os
import sys

# Agrega la ruta raíz del proyecto si no está
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from services.Graficado.graficar_series_y_guardar import *
from services.Graficado.graficar_mapa_de_posiciones import *
from services.Graficado.graficar_mapa_de_despliegue import *
##################################################################################

# %%
# Esta figura se hace usando los datos de lab y los datos de la página web.
graficar_series_y_guardar(mostrar_figura=False) # Revisar los n_ticks en calcular_xticks ; esto sigue mal
# Out:
# c:\Users\Atmosfera\Documents\drift_buoys\Procesar_datos\services\Graficado\base\Gra_dar_formato_a_figuras.py:483: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   obj_axes.set_ylim(ylim_min, ylim_max)
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\SONDA_OCEANOGRAFICA_NS_4910070_REALT_20260523_20260524.png
# c:\Users\Atmosfera\Documents\drift_buoys\Procesar_datos\services\Graficado\base\Gra_dar_formato_a_figuras.py:483: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   obj_axes.set_ylim(ylim_min, ylim_max)
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\SONDA_OCEANOGRAFICA_NS_4912213_REALT_20260523_20260524.png
# c:\Users\Atmosfera\Documents\drift_buoys\Procesar_datos\services\Graficado\base\Gra_dar_formato_a_figuras.py:483: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   obj_axes.set_ylim(ylim_min, ylim_max)
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\SONDA_OCEANOGRAFICA_NS_4904116_REALT_20260523_20260524.png
# c:\Users\Atmosfera\Documents\drift_buoys\Procesar_datos\services\Graficado\base\Gra_dar_formato_a_figuras.py:483: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   obj_axes.set_ylim(ylim_min, ylim_max)
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\SONDA_OCEANOGRAFICA_NS_4901427_REALT_20260523_20260524.png
# c:\Users\Atmosfera\Documents\drift_buoys\Procesar_datos\services\Graficado\base\Gra_dar_formato_a_figuras.py:483: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   obj_axes.set_ylim(ylim_min, ylim_max)
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\SONDA_OCEANOGRAFICA_NS_4912212_REALT_20260523_20260524.png

# %%
# Este mapa se hace usando los datos de lab y los datos de la página web.
graficar_mapa_con_posiciones(mostrar_figura=False)
# Out:
# c:\Users\Atmosfera\Documents\drift_buoys\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# sonda 4910070 lat ini= 18.641465, lon ini= -91.786799
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\MAPA_DE_TRAYECTORIAS_SONDA_OCEANOGRAFICANS_4910070_REALT_20260523_20260524.png
# sonda 4912213 lat ini= 18.641277, lon ini= -91.786677
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\MAPA_DE_TRAYECTORIAS_SONDA_OCEANOGRAFICANS_4912213_REALT_20260523_20260524.png
# sonda 4904116 lat ini= 18.641971, lon ini= -91.786669
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\MAPA_DE_TRAYECTORIAS_SONDA_OCEANOGRAFICANS_4904116_REALT_20260523_20260524.png
# sonda 4901427 lat ini= 18.64181, lon ini= -91.786844
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\MAPA_DE_TRAYECTORIAS_SONDA_OCEANOGRAFICANS_4901427_REALT_20260523_20260524.png
# sonda 4912212 lat ini= 18.641409, lon ini= -91.787258
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202605\MAPA_DE_TRAYECTORIAS_SONDA_OCEANOGRAFICANS_4912212_REALT_20260523_20260524.png
