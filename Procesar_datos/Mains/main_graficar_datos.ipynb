# %% [markdown]
# <b>Código principal para graficar los datos.</b>
# <p> Configurar fechas de carga, seriales de boyas y rutas para archivos en \Configs\configuracion_general.py </p>

# %%
####################### N O  T O C A R ############################################
# %load_ext autoreload
# %autoreload 2

import os
import sys

# Agrega la ruta raíz del proyecto si no está
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from services.Graficado.graficar_series_y_guardar import *
from services.Graficado.graficar_mapa_de_posiciones import *
from services.Graficado.graficar_mapa_de_despliegue import *
##################################################################################

# %%
# Esta figura se hace usando los datos de lab y los datos de la página web.
graficar_series_y_guardar(mostrar_figura=False) # Revisar los n_ticks en calcular_xticks ; esto sigue mal
# Out:
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202603\SONDA_OCEANOGRAFICA_NS_4876179_REALT_20260326_20260331.png
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202603\SONDA_OCEANOGRAFICA_NS_4912197_REALT_20260326_20260331.png
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202603\SONDA_OCEANOGRAFICA_NS_4887980_REALT_20260326_20260331.png
# c:\programacion\codigos_python\drift_buoys\Procesar_datos\services\Graficado\base\Gra_dar_formato_a_figuras.py:483: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   obj_axes.set_ylim(ylim_min, ylim_max)
# Figura guardada correctamente en C:\Users\Atmosfera\Desktop\datos_procesados\doris\10.3\202603\SONDA_OCEANOGRAFICA_NS_4866660_REALT_20260326_20260326.png

# %%
# Este mapa se hace usando los datos de lab y los datos de la página web.
graficar_mapa_con_posiciones(mostrar_figura=False)
