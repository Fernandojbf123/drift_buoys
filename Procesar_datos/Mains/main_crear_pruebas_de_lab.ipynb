# %%
####################### N O  T O C A R ############################################
# %load_ext autoreload
# %autoreload 2

import os
import sys

# Agrega la ruta raíz del proyecto si no está
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from services.Pruebas_lab.pruebas_lab_utils import *
##################################################################################

# %%
# seriales = ["4878319"]
# seriales = ["4876179", "4912197", "4887980", "4866660"]
# seriales = ["4876179", "4912197", "4887980", "4866660"]
# fecha_ini = pd.to_datetime("2026-05-23 15:00:00")
# fecha_fin = pd.to_datetime("2026-05-24 16:00:00")   
fecha_ini = pd.to_datetime("2026-06-25 15:00:00")
fecha_fin = pd.to_datetime("2026-06-26 16:00:00")  
# seriales = ["9878221","9878504", "9878225", "9876178","9878203"] # 18 de abril 2026
# seriales = ["4910070","4912213", "4904116", "4901427","4912212"] # 26 de mayo  2026
seriales = ["4857577", "4909282", "4912199", "4912171", "4907604"] # 27 de junio  2026

# fecha_ini = pd.to_datetime("2026-04-16 15:00:00")
# fecha_fin = pd.to_datetime("2026-04-17 16:00:00")   
# seriales = ["9878221","9878504", "9878225", "9876178","9878203"] # 18 de abril 2026
# fecha_ini = pd.to_datetime("2026-04-23 15:00:00")
# fecha_fin = pd.to_datetime("2026-04-24 16:00:00")
# seriales = ["4878505","9878218"] # 26 de abril 2026

fecha_ini = pd.to_datetime("2026-05-23 15:00:00")
fecha_fin = pd.to_datetime("2026-05-24 16:00:00")   
seriales = ["4910070","4912213", "4904116", "4901427","4912212"] # 26 de mayo 2026
ruta_a_carpeta = "C:\\Users\\Atmosfera\\Desktop\\datos_procesados\\doris\\10.1\\202605\\pruebas_lab" #Acuerdate de crear la carpeta

# %%
diccionarios = {}
for serial in seriales:
    dic = generar_datos(fecha_inicio=fecha_ini, fecha_fin=fecha_fin, periodo=30, variacion=0)
    df = pd.DataFrame(dic)
    diccionarios[serial] = df
    file_path = os.path.join(ruta_a_carpeta, f"prueba_en_tierra_{serial}_TOTAL.csv")
    df.to_csv(file_path, index=False)

# %%
# diccionarios["4878221"].head()

# %%
df
