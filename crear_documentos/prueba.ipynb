# %%
# %load_ext autoreload
# %autoreload 2

# %%
from services.manager_variables_excel_datos_doris import *

# %%
df = get_df_datos_doris()
df_filtrado = filtrar_df_datos_doris_por_orden_de_servicio(df)
# Out:
# c:\programacion\codigos_python\drift_buoys\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
df.tail(11)
# Out:
#     serial_de_sonda   OS  mes_vigencia  serial_original serial_UABC  \
# 28          9878221  202           NaN          4878221         NaN
# 29          9878504  202           NaN          4878504         NaN
# 30          9878225  202           NaN          4878225         NaN
# 31          9876178  202           NaN          4876178         NaN
# 32          9878203  202           NaN          4878203         NaN
# 33          9878218  202           NaN          4878218         NaN
# 34          4878505  202           NaN          4878505         NaN
#
#    fecha_y_hora_de_despliegue_campo  \
# 28              2026-04-19 18:00:00
# 29              2026-04-19 18:00:00
# 30              2026-04-19 18:00:00
# 31              2026-04-19 18:00:00
# 32              2026-04-19 18:00:00
# 33                              NaT
# 34                              NaT
#
#    fecha_y_hora_de_la_primera_transmision_campo latitud_de_despliegue_campo  \
# 28                          2026-04-19 18:00:00                         NaN
# 29                          2026-04-19 18:00:00                         NaN
# 30                          2026-04-19 18:00:00                         NaN
# 31                          2026-04-19 18:00:00                         NaN
# 32                          2026-04-19 18:00:00                         NaN
# 33                                          NaT                         NaN
# 34                                          NaT                         NaN
#
#    longitud_de_despliegue_campo  tirante_de_despligue_campo  ...  \
# 28                          NaN                         NaN  ...
# 29                          NaN                         NaN  ...
# 30                          NaN                         NaN  ...
# 31                          NaN                         NaN  ...
# 32                          NaN                         NaN  ...
# 33                          NaN                         NaN  ...
# 34                          NaN                         NaN  ...
#
#    longitud_maniobra  fecha_y_hora_de_despliegue_plan latitud_plan  \
# 28               NaN              2026-04-18 17:59:00    19.354231
# 29        -92.140274              2026-04-18 18:01:00    19.358000
# 30        -92.148471              2026-04-18 18:12:00    19.365000
# 31        -92.239752              2026-04-18 18:22:00    19.502000
# 32        -92.250652              2026-04-18 18:59:00    19.531000
# 33        -93.326375              2026-04-26 18:23:00    18.727000
# 34        -93.266575              2026-04-26 17:02:00    18.801000
#
#    longitud_plan fecha_y_hora_de_ultima_medicion buoy_id  FechaInicial Local  \
# 28    -92.134043                             NaN     NaN 2026-03-26 12:01:00
# 29    -92.140000                             NaN     NaN 2026-03-26 12:03:00
# 30    -92.148000                             NaN     NaN 2026-03-26 12:14:00
# 31    -92.239000                             NaN     NaN 2026-03-26 12:24:00
# 32    -92.250000                             NaN     NaN 2026-03-26 13:01:00
# 33    -93.326000                             NaN     NaN                 NaT
# 34    -93.266000                             NaN     NaN                 NaT
#
#        FechaFinal Local hora_de_la_ultima_fila_eliminada  \
# 28  2026-03-26 12:01:00                              NaN
# 29                  NaN                              NaN
# 30                  NaN                              NaN
# 31                  NaN                              NaN
# 32                  NaN                              NaN
# 33                  NaN                              NaN
# 34                  NaN                              NaN
#
#    aux_para_nombres_de_sensores
# 28                          S28
# 29                          S29
# 30                          S30
# 31                          S31
# 32                          S32
# 33                          S34
# 34                          S33
#
# [7 rows x 36 columns]

# %%
df_filtrado.head(10)
# Out:
#     serial_de_sonda   OS  mes_vigencia  serial_original serial_UABC  \
# 28          9878221  202           NaN          4878221         NaN
# 29          9878504  202           NaN          4878504         NaN
# 30          9878225  202           NaN          4878225         NaN
# 31          9876178  202           NaN          4876178         NaN
# 32          9878203  202           NaN          4878203         NaN
# 33          9878218  202           NaN          4878218         NaN
# 34          4878505  202           NaN          4878505         NaN
#
#    fecha_y_hora_de_despliegue_campo  \
# 28              2026-04-19 18:00:00
# 29              2026-04-19 18:00:00
# 30              2026-04-19 18:00:00
# 31              2026-04-19 18:00:00
# 32              2026-04-19 18:00:00
# 33                              NaT
# 34                              NaT
#
#    fecha_y_hora_de_la_primera_transmision_campo latitud_de_despliegue_campo  \
# 28                          2026-04-19 18:00:00                         NaN
# 29                          2026-04-19 18:00:00                         NaN
# 30                          2026-04-19 18:00:00                         NaN
# 31                          2026-04-19 18:00:00                         NaN
# 32                          2026-04-19 18:00:00                         NaN
# 33                                          NaT                         NaN
# 34                                          NaT                         NaN
#
#    longitud_de_despliegue_campo  tirante_de_despligue_campo  ...  \
# 28                          NaN                         NaN  ...
# 29                          NaN                         NaN  ...
# 30                          NaN                         NaN  ...
# 31                          NaN                         NaN  ...
# 32                          NaN                         NaN  ...
# 33                          NaN                         NaN  ...
# 34                          NaN                         NaN  ...
#
#    longitud_maniobra  fecha_y_hora_de_despliegue_plan latitud_plan  \
# 28               NaN              2026-04-18 17:59:00    19.354231
# 29        -92.140274              2026-04-18 18:01:00    19.358000
# 30        -92.148471              2026-04-18 18:12:00    19.365000
# 31        -92.239752              2026-04-18 18:22:00    19.502000
# 32        -92.250652              2026-04-18 18:59:00    19.531000
# 33        -93.326375              2026-04-26 18:23:00    18.727000
# 34        -93.266575              2026-04-26 17:02:00    18.801000
#
#    longitud_plan fecha_y_hora_de_ultima_medicion buoy_id  FechaInicial Local  \
# 28    -92.134043                             NaN     NaN 2026-03-26 12:01:00
# 29    -92.140000                             NaN     NaN 2026-03-26 12:03:00
# 30    -92.148000                             NaN     NaN 2026-03-26 12:14:00
# 31    -92.239000                             NaN     NaN 2026-03-26 12:24:00
# 32    -92.250000                             NaN     NaN 2026-03-26 13:01:00
# 33    -93.326000                             NaN     NaN                 NaT
# 34    -93.266000                             NaN     NaN                 NaT
#
#        FechaFinal Local hora_de_la_ultima_fila_eliminada  \
# 28  2026-03-26 12:01:00                              NaN
# 29                  NaN                              NaN
# 30                  NaN                              NaN
# 31                  NaN                              NaN
# 32                  NaN                              NaN
# 33                  NaN                              NaN
# 34                  NaN                              NaN
#
#    aux_para_nombres_de_sensores
# 28                          S28
# 29                          S29
# 30                          S30
# 31                          S31
# 32                          S32
# 33                          S34
# 34                          S33
#
# [7 rows x 36 columns]

# %%
latitudes = get_latitudes(df_filtrado)
latitudes
# Out:
# [nan, 19.358039, 19.365968, 19.50246, 19.531374, 18.727398, 18.8015922]

# %%
longitudes = get_longitudes(df_filtrado)
longitudes
# Out:
# [nan, -92.140274, -92.148471, -92.239752, -92.250652, -93.326375, -93.266575]
