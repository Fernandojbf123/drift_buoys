# %%
# %load_ext autoreload
# %autoreload 2

# %%
from services.abrir_plantilla_doris import abrir_plantilla_doris
from services.manager_variables_excel_datos_despliegue import *
from services.manager_variables_excel_datos_campania import *
from services.manager_variables_excel_documento import *
from services.constructor_diccionario_datos_documento import *
# from services.doc_101.introduccion.intro_parrafo1 import *    
# from services.doc_101.alcances.alcances_parrafo1 import *
# from services.doc_101.descripcion_actividades_previas.descripcion_actividades_previas_parrafo1 import *
# from services.doc_101.descripcion_actividades_previas.descripcion_actividades_previas_parrafo2 import *
# # from services.doc_101.descripcion_actividades_previas.descripcion_actividades_previas_parrafo3 import *
# # from services.doc_101.ejecucion_de_la_campania.ejecucion_de_la_campania_parrafo1 import *
# # from services.doc_101.ejecucion_de_la_campania.ejecucion_de_la_campania_parrafo2 import *
# from services.doc_101.ejecucion_de_la_campania.ejecucion_de_la_campania_parrafo3 import *
# from services.doc_101.conclusiones.conclusiones_parrafo1 import *
# # from services.doc_101.conclusiones.conclusiones_parrafo2 import *

from services.reemplazar_en_word import *
from services.guardar_documento import guardar_documento

# %%
df_datos_despliegue = get_df_datos_despliegue()
df_datos_despliegue_filtrado = filtrar_df_datos_despliegue_por_orden_de_servicio(df_datos_despliegue)
seriales_de_sondas = get_seriales_de_sondas(df_datos_despliegue_filtrado)
df_campanias = get_df_datos_campanias()
df_campanias_filtrado = filtrar_datos_de_campanias(df_datos_campanias = df_campanias, seriales_de_sondas = seriales_de_sondas)
df_documento = get_df_datos_documento()
# Out:
# c:\programacion\codigos_python\drift_buoys\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# c:\programacion\codigos_python\drift_buoys\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
dict_demo = construir_diccionario_agregar_figuras(df_datos_documento = df_documento)

# %%
dict_demo["<<fig_pruebas_transmision>>"]
# Out:
# [{'ruta': '//192.168.15.249\\Med_2025-2026\\Reportes_Edit\\Reporte_10.1\\202604\\documento\\prueba_transmision_serial1.jpg',
#   'titulo': 'Datos enviados durante las pruebas de laboratorio para la sonda serial1',
#   'tamanio': 3,
#   'bookmark': 'Ref_prueba_transmision_serial1'},
#  {'ruta': '//192.168.15.249\\Med_2025-2026\\Reportes_Edit\\Reporte_10.1\\202604\\documento\\prueba_transmision_serial2.jpg',
#   'titulo': 'Datos enviados durante las pruebas de laboratorio para la sonda serial2',
#   'tamanio': 3,
#   'bookmark': 'Ref_prueba_transmision_serial2'},
#  {'ruta': '//192.168.15.249\\Med_2025-2026\\Reportes_Edit\\Reporte_10.1\\202604\\documento\\prueba_transmision_serial3.jpg',
#   'titulo': 'Datos enviados durante las pruebas de laboratorio para la sonda serial3',
#   'tamanio': 3,
#   'bookmark': 'Ref_prueba_transmision_serial3'},
#  {'ruta': '//192.168.15.249\\Med_2025-2026\\Reportes_Edit\\Reporte_10.1\\202604\\documento\\prueba_transmision_serial4.jpg',
#   'titulo': 'Datos enviados durante las pruebas de laboratorio para la sonda serial4',
#   'tamanio': 3,
#   'bookmark': 'Ref_prueba_transmision_serial4'},
#  {'ruta': '//192.168.15.249\\Med_2025-2026\\Reportes_Edit\\Reporte_10.1\\202604\\documento\\prueba_transmision_serial5.jpg',
#   'titulo': 'Datos enviados durante las pruebas de laboratorio para la sonda serial5',
#   'tamanio': 3,
#   'bookmark': 'Ref_prueba_transmision_serial5'},
#  {'ruta': '//192.168.15.249\\Med_2025-2026\\Reportes_Edit\\Reporte_10.1\\202604\\documento\\prueba_transmision_serial6.jpg',
#   'titulo': 'Datos enviados durante las pruebas de laboratorio para la sonda serial6',
#   'tamanio': 3,
#   'bookmark': 'Ref_prueba_transmision_serial6'},
#  {'ruta': '//192.168.15.249\\Med_2025-2026\\Reportes_Edit\\Reporte_10.1\\202604\\documento\\prueba_transmision_serial7.jpg',
#   'titulo': 'Datos enviados durante las pruebas de laboratorio para la sonda serial7',
#   'tamanio': 3,
#   'bookmark': 'Ref_prueba_transmision_serial7'}]

# %%
doc = abrir_plantilla_doris(get_ruta_a_la_plantilla_de_word())

# %%
### DEMO DE DICCIONARIO -- PONER FIGURAS ---
# dict_demo = {
#     "<<fig_demo_con_titulo>>": [
#         {"ruta": "C:\\Users\\Atmosfera\\Desktop\\datos_procesados\\doris\\10.1\\202604\\fig_demo_con_titulo_1.png", "titulo": "Acá van otras cosas. Quien sabe que.", "tamanio": 6, "bookmark": "Ref_demo_con_titulo_1"},
#         {"ruta": "C:\\Users\\Atmosfera\\Desktop\\datos_procesados\\doris\\10.1\\202604\\fig_demo_con_titulo_2.png", "titulo": "Este es el titulo de figura 2. Tiene mucho texto y por eso debería tener 2 lineas y usar el estilo Car_justificado. Esta es una prueba del funcionamiento de la aplicación de estilos.", "tamanio": 6, "bookmark": "Ref_demo_con_titulo_2"},
#     ]
# }

# dict_demo = {
#     "<<fig_demo_sin_titulo>>": [
#         {"ruta": "C:\\Users\\Atmosfera\\Desktop\\datos_procesados\\doris\\10.1\\202604\\fig_demo_sin_titulo_1.png", "titulo": "", "tamanio": 6, "bookmark": ""},
#     ],
#     "<<fig_demo_con_titulo>>": [
#         {"ruta": "C:\\Users\\Atmosfera\\Desktop\\datos_procesados\\doris\\10.1\\202604\\fig_demo_con_titulo_1.png", "titulo": "Acá van otras cosas. Quien sabe que.", "tamanio": 6, "bookmark": "Ref_demo_con_titulo_1"},
#         {"ruta": "C:\\Users\\Atmosfera\\Desktop\\datos_procesados\\doris\\10.1\\202604\\fig_demo_con_titulo_2.png", "titulo": "Este es el titulo de figura 2. Tiene mucho texto y por eso debería tener 2 lineas y usar el estilo que merece.", "tamanio": 6, "bookmark": "Ref_demo_con_titulo_2"},
#         {"ruta": "C:\\Users\\Atmosfera\\Desktop\\datos_procesados\\doris\\10.1\\202604\\fig_demo_con_titulo_3.png", "titulo": "Este es el titulo de figura 3. Tiene mucho texto y por eso debería tener.", "tamanio": 6, "bookmark": "Ref_demo_con_titulo_3"}
#     ]
# }

# %%
bookmarks = insertar_figuras_en_plantilla(doc = doc, diccionario_de_reemplazos = dict_demo)

# %%
dict_demo = dict_demo | bookmarks

# %%
insertar_referencias_cruzadas_en_plantilla(doc = doc, bookmarks_info = dict_demo)

# %%
# reemplazar_texto_en_word(doc = doc, diccionario_de_reemplazos = dict_demo)

# %%
guardar_documento(doc, nombre_archivo="prueba_imagenes.docx")
# Out:
# Documento guardado en: //192.168.15.249\Med_2025-2026\Reportes_Edit\Reporte_10.1\202604\documento\prueba_imagenes.docx
# '//192.168.15.249\\Med_2025-2026\\Reportes_Edit\\Reporte_10.1\\202604\\documento\\prueba_imagenes.docx'

# %%
dic_introduccion = {}
dic_introduccion["<<intro_parrafo1>>"] = intro_parrafo1(dic_datos_doris = {})

# %%
dic_introduccion

# %%
dic_alcances = {}
dic_alcances["<<alcances_parrafo1>>"] = alcances_parrafo1(dic_datos_doris = {})

# %%
dic_alcances

# %%
dic_descripcion_actividades_previas = {}
dic_descripcion_actividades_previas["<<descripcion_actividades_previas_parrafo1>>"] = descripcion_actividades_previas_parrafo1(dic_datos_doris = {})
dic_descripcion_actividades_previas["<<descripcion_actividades_previas_parrafo2>>"] = descripcion_actividades_previas_parrafo2(dic_datos_doris = {})
dic_descripcion_actividades_previas["<<descripcion_actividades_previas_parrafo3>>"] = descripcion_actividades_previas_parrafo3(dic_datos_doris = {})
