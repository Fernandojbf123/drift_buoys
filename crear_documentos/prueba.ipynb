# %%
# %load_ext autoreload
# %autoreload 2

# %%
from services.abrir_plantilla_doris import abrir_plantilla_doris
from services.manager_variables_excel_datos_despliegue import *
from services.manager_variables_excel_datos_campania import *
from services.manager_variables_excel_documento import *
from services.doc_101.constructor_diccionario_datos_documento import *
from services.word_template_writer import *
from services.guardar_documento import guardar_documento

# %%
df_datos_despliegue = get_df_datos_despliegue()
df_datos_despliegue_filtrado = filtrar_df_datos_despliegue_por_orden_de_servicio(df_datos_despliegue)
seriales_de_sondas = get_seriales_de_sondas(df_datos_despliegue_filtrado)
df_campanias = get_df_datos_campanias()
df_campanias_filtrado = filtrar_datos_de_campanias(df_datos_campanias = df_campanias, seriales_de_sondas = seriales_de_sondas)
df_documento = get_df_datos_documento()
df_documento
# Out:
# c:\Users\Atmosfera\Documents\drift_buoys\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# c:\Users\Atmosfera\Documents\drift_buoys\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#                                 0   \
# 0                 anio_de_vigencia
# 1                  mes_de_vigencia
# 2   fig_descripcion_arquitectura_1
# 3   pie_descripcion_arquitectura_1
# 4   fig_descripcion_arquitectura_2
# 5   pie_descripcion_arquitectura_2
# 6   fig_descripcion_arquitectura_3
# 7   pie_descripcion_arquitectura_3
# 8   fig_descripcion_arquitectura_4
# 9   pie_descripcion_arquitectura_4
# 10  fig_descripcion_arquitectura_5
# 11  pie_descripcion_arquitectura_5
# 12  fig_descripcion_arquitectura_6
# 13  pie_descripcion_arquitectura_6
# 14         fig_actividades_previas
# 15         pie_actividades_previas
# 16          fig_mapa_de_despliegue
# 17          pie_mapa_de_despliegue
# 18    fig_ejecucion_de_la_campania
# 19          pie_ejecucion_campania
# 20            fig_esquema_de_sonda
# 21            fig_pruebas_baterias
# 22   fig_ubicacion_durante_pruebas
# 23   fig_pruebas_de_funcionamiento
# 24      fig_pruebas_de_transmision
# 25            ruta_plan_de_crucero
# 26           fig_anexo_fotografico
# 27   descripcion_anexo_fotografico
#
#                                                    1   \
# 0                                                2026
# 1                                               junio
# 2                          descripcion_arquitectura_1
# 3             Esfera de flotación durante el sellado.
# 4                          descripcion_arquitectura_2
# 5    Draga de arrastre durante las pruebas de func...
# 6                          descripcion_arquitectura_3
# 7      Tarjeta madre con microcontrolador de 32 bits.
# 8                          descripcion_arquitectura_4
# 9   Panel solar de la sonda oceanográfica, equipo ...
# 10                         descripcion_arquitectura_5
# 11  Interior de la boya rellena de poliuretano des...
# 12                         descripcion_arquitectura_6
# 13               Módulo de posicionamiento GPS listo.
# 14                    descripcion_actividades_previas
# 15  Proceso de sellado de la boya, limpieza de la ...
# 16                               mapa_de_despliegue_1
# 17             Sondas liberadas en la campaña ASM-212
# 18                         ejecucion_de_la_campania_1
# 19  Sondas oceanográficas resguardadas previo al d...
# 20                              esquema_sonda_4857577
# 21                                 pruebas_baterias_1
# 22                                 mapa_de_prueba_lab
# 23                                      4857577_sat_1
# 24                      prueba_de_transmision_4857577
# 25  \\192.168.15.249\Med_2025-2026\Reportes_Edit\P...
# 26                                              foto1
# 27  Transporte de equipo y sondas al sitio de emba...
#
#                                                 2   \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                                             NaN
# 18                      ejecucion_de_la_campania_2
# 19      Sonda oceanográfica previo a su liberación
# 20                           esquema_sonda_4909282
# 21                                             NaN
# 22                                             NaN
# 23                                   4857577_sat_2
# 24                   prueba_de_transmision_4909282
# 25                                             NaN
# 26                                           foto2
# 27  Encendido de las sondas antes del despliegue.
#
#                                           3   \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                ejecucion_de_la_campania_3
# 19            Sonda oceanográfica y posición
# 20                     esquema_sonda_4912199
# 21                                       NaN
# 22                                       NaN
# 23                             4857577_sat_3
# 24             prueba_de_transmision_4912199
# 25                                       NaN
# 26                                     foto3
# 27  Despliegue de las sondas oceanográficas.
#
#                                     4                                5   \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
# 5                                  NaN                              NaN
# 6                                  NaN                              NaN
# 7                                  NaN                              NaN
# 8                                  NaN                              NaN
# 9                                  NaN                              NaN
# 10                                 NaN                              NaN
# 11                                 NaN                              NaN
# 12                                 NaN                              NaN
# 13                                 NaN                              NaN
# 14                                 NaN                              NaN
# 15                                 NaN                              NaN
# 16                                 NaN                              NaN
# 17                                 NaN                              NaN
# 18          ejecucion_de_la_campania_4       ejecucion_de_la_campania_5
# 19  Despliegue de la draga de arrastre  Sonda oceanográfica en posicion
# 20               esquema_sonda_4912171            esquema_sonda_4907604
# 21                                 NaN                              NaN
# 22                                 NaN                              NaN
# 23                       4909282_sat_1                    4909282_sat_2
# 24       prueba_de_transmision_4912171    prueba_de_transmision_4907604
# 25                                 NaN                              NaN
# 26                                 NaN                              NaN
# 27                                 NaN                              NaN
#
#                                6                                           7   \
# 0                             NaN                                         NaN
# 1                             NaN                                         NaN
# 2                             NaN                                         NaN
# 3                             NaN                                         NaN
# 4                             NaN                                         NaN
# 5                             NaN                                         NaN
# 6                             NaN                                         NaN
# 7                             NaN                                         NaN
# 8                             NaN                                         NaN
# 9                             NaN                                         NaN
# 10                            NaN                                         NaN
# 11                            NaN                                         NaN
# 12                            NaN                                         NaN
# 13                            NaN                                         NaN
# 14                            NaN                                         NaN
# 15                            NaN                                         NaN
# 16                            NaN                                         NaN
# 17                            NaN                                         NaN
# 18     ejecucion_de_la_campania_6                  ejecucion_de_la_campania_7
# 19  Sonda con su draga desplegada  Sonda oceanográfica previo a su liberación
# 20                            NaN                                         NaN
# 21                            NaN                                         NaN
# 22                            NaN                                         NaN
# 23                  4909282_sat_3                               4912171_sat_1
# 24                            NaN                                         NaN
# 25                            NaN                                         NaN
# 26                            NaN                                         NaN
# 27                            NaN                                         NaN
#
#                8              9              10             11             12  \
# 0             NaN            NaN            NaN            NaN            NaN
# 1             NaN            NaN            NaN            NaN            NaN
# 2             NaN            NaN            NaN            NaN            NaN
# 3             NaN            NaN            NaN            NaN            NaN
# 4             NaN            NaN            NaN            NaN            NaN
# 5             NaN            NaN            NaN            NaN            NaN
# 6             NaN            NaN            NaN            NaN            NaN
# 7             NaN            NaN            NaN            NaN            NaN
# 8             NaN            NaN            NaN            NaN            NaN
# 9             NaN            NaN            NaN            NaN            NaN
# 10            NaN            NaN            NaN            NaN            NaN
# 11            NaN            NaN            NaN            NaN            NaN
# 12            NaN            NaN            NaN            NaN            NaN
# 13            NaN            NaN            NaN            NaN            NaN
# 14            NaN            NaN            NaN            NaN            NaN
# 15            NaN            NaN            NaN            NaN            NaN
# 16            NaN            NaN            NaN            NaN            NaN
# 17            NaN            NaN            NaN            NaN            NaN
# 18            NaN            NaN            NaN            NaN            NaN
# 19            NaN            NaN            NaN            NaN            NaN
# 20            NaN            NaN            NaN            NaN            NaN
# 21            NaN            NaN            NaN            NaN            NaN
# 22            NaN            NaN            NaN            NaN            NaN
# 23  4912171_sat_2  4912171_sat_3  4912199_sat_1  4912199_sat_2  4912199_sat_3
# 24            NaN            NaN            NaN            NaN            NaN
# 25            NaN            NaN            NaN            NaN            NaN
# 26            NaN            NaN            NaN            NaN            NaN
# 27            NaN            NaN            NaN            NaN            NaN
#
#                13             14             15
# 0             NaN            NaN            NaN
# 1             NaN            NaN            NaN
# 2             NaN            NaN            NaN
# 3             NaN            NaN            NaN
# 4             NaN            NaN            NaN
# 5             NaN            NaN            NaN
# 6             NaN            NaN            NaN
# 7             NaN            NaN            NaN
# 8             NaN            NaN            NaN
# 9             NaN            NaN            NaN
# 10            NaN            NaN            NaN
# 11            NaN            NaN            NaN
# 12            NaN            NaN            NaN
# 13            NaN            NaN            NaN
# 14            NaN            NaN            NaN
# 15            NaN            NaN            NaN
# 16            NaN            NaN            NaN
# 17            NaN            NaN            NaN
# 18            NaN            NaN            NaN
# 19            NaN            NaN            NaN
# 20            NaN            NaN            NaN
# 21            NaN            NaN            NaN
# 22            NaN            NaN            NaN
# 23  4907604_sat_1  4907604_sat_2  4907604_sat_3
# 24            NaN            NaN            NaN
# 25            NaN            NaN            NaN
# 26            NaN            NaN            NaN
# 27            NaN            NaN            NaN

# %%
doc = abrir_plantilla_doris(get_ruta_a_la_plantilla_de_word())
dict_demo = construir_diccionario_agregar_figuras(df_datos_documento = df_documento)
# 
construir_diccionario_de_datos_documento(df_datos_despliegue = df_datos_despliegue_filtrado,
                                        df_datos_campanias = df_campanias_filtrado,
                                        df_datos_documento = df_documento,
                                        diccionario_de_reemplazos = dict_demo)

construir_diccionario_de_reemplazos_para_plan_de_cruceros(df_datos_despliegue = df_datos_despliegue_filtrado,
                                                            df_datos_campanias = df_campanias_filtrado,
                                                            df_datos_documento = df_documento,
                                                            diccionario_de_reemplazos = dict_demo)

construir_diccionario_de_reemplazos_para_tablas(df_datos_despliegue = df_datos_despliegue_filtrado,
                                                df_datos_campanias = df_campanias_filtrado,
                                                df_datos_documento = df_documento,
                                                diccionario_de_reemplazos = dict_demo,
                                                doc = doc)

# %%
insertar_figuras_en_plantilla(doc = doc, diccionario_de_reemplazos = dict_demo)
insertar_referencias_cruzadas_en_plantilla(doc = doc, diccionario_de_reemplazos = dict_demo)
reemplazar_texto_en_plantilla(doc = doc, diccionario_de_reemplazos = dict_demo)
reemplazar_variables_en_tablas(doc = doc, diccionario_de_reemplazos = dict_demo)
insertar_documento_externo_en_plantilla(doc = doc, diccionario_de_reemplazos = dict_demo)
rellenar_tablas_en_plantilla(doc = doc, diccionario_de_reemplazos = dict_demo)
# Out:
# Figuras insertadas y bookmarks creados para referencias cruzadas
# Referencias cruzadas insertadas.
# Se agregaron los textos al documento.
# Se reemplazaron las variables en las tablas del documento.
# Documento insertado <<external_doc_plan_de_crucero>>
# Tabla '<<tabla_plan>>' rellenada correctamente.
# Tabla '<<tabla_maniobra>>' rellenada correctamente.
# Tabla '<<tabla_equipos>>' rellenada correctamente.

# %%
guardar_documento(doc, nombre_archivo="ASM-CICESE-Concepto_10.1_20260501_rev_00.docx")
# Out:
# Documento guardado en: //192.168.15.249\Med_2025-2026\Reportes_Edit\Reporte_10.1\202606\documento\ASM-CICESE-Concepto_10.1_20260501_rev_00.docx
# '//192.168.15.249\\Med_2025-2026\\Reportes_Edit\\Reporte_10.1\\202606\\documento\\ASM-CICESE-Concepto_10.1_20260501_rev_00.docx'

# %%
import psutil

for p in psutil.process_iter(["name"]):
    if p.info.get("name") and "POWERPNT.EXE" in p.info["name"]:
        p.terminate()
